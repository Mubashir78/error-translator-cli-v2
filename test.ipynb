# %%
# %reload_ext src.error_translator.jupyter
# Out:
# Error Translator disabled.
# > **Error Translator loaded!** Any unhandled crashes in this notebook will now be translated.

# %%
import bs4 as b

# %%
right = 4

# %%
print(right / 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(right / 0)
#
# ZeroDivisionError: division by zero
# ---
# ### Error Translator Insight
#
# **Detected Error:** ZeroDivisionError: division by zero
#
# **Explanation:** You are trying to divide a number by zero, which is mathematically impossible.
#
# **Suggested Fix:** Add an if-statement before the division to check if the denominator is 0.
#
# ---
